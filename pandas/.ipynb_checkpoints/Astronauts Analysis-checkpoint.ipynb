# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("astronauts.csv")

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
df.shape
# Out:
# (357, 19)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
# df.rename(columns = {"Birth Date": "birth_date", "Birth Place": "birth_place",
#                     'Alma Mater': 'alma_mater',
#                      'Undergraduate Major': 'undergraduate_major',
#                      'Military Rank': 'military_rank', 
#                      'Military Branch': 'military_branch', 
#                      'Space Flights': 'space_flights',
#                      'Space Flight (hr)':'space_flight(hr)',
#                      'Space Walks': 'space_walks',
#                      'Space Walks (hr)': 'space_walks(hr)',
#                      'Death Date': 'death_date',
#                      'Death Mission': 'death_mission',
#                      'Graduate Major': 'graduate_major',
                     
#                     }, inplace=True)

# %%
col = list(df.columns)
for i in range(len(col)):
    col[i] = col[i].lower().replace(" ", "_")
#     print(i.lower().replace(" ", "_"))

# %%
df.columns = col

# %%
df.head(10)
# Out:
#                   name    year  group   status  birth_date  \
# 0      Joseph M. Acaba  2004.0   19.0   Active   5/17/1967
# 1       Loren W. Acton     NaN    NaN  Retired    3/7/1936
# 2     James C. Adamson  1984.0   10.0  Retired    3/3/1946
# 3      Thomas D. Akers  1987.0   12.0  Retired   5/20/1951
# 4          Buzz Aldrin  1963.0    3.0  Retired   1/20/1930
# 5      Andrew M. Allen  1987.0   12.0  Retired    8/4/1955
# 6      Joseph P. Allen  1967.0    6.0  Retired   6/27/1937
# 7      Scott D. Altman  1995.0   15.0  Retired   8/15/1959
# 8    William A. Anders  1963.0    3.0  Retired  10/17/1933
# 9  Clayton C. Anderson  1998.0   17.0  Retired   2/23/1959
#
#            birth_place gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# 5     Philadelphia, PA   Male
# 6  Crawsfordsville, IN   Male
# 7          Lincoln, IL   Male
# 8            Hong Kong   Male
# ...

# %%
df.tail(3)
# Out:
#                  name    year  group   status birth_date        birth_place  \
# 354  Alfred M. Worden  1966.0    5.0  Retired   2/7/1932        Jackson, MI
# 355     John W. Young  1962.0    2.0  Retired  9/24/1930  San Francisco, CA
# 356   George D. Zamka  1998.0   17.0  Retired  6/29/1962    Jersey City, NJ
#
#     gender                                         alma_mater  \
# 354   Male        US Military Academy; University of Michigan
# 355   Male                    Georgia Institute of Technology
# 356   Male  US Naval Academy; Florida Institute of Technology
#
#           undergraduate_major                            graduate_major  \
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     military_rank            military_branch  space_flights  \
# ...

# %%
df.sample(3)
# Out:
#                       name    year  group      status birth_date  \
# 113     Michael J. Foreman  1998.0   17.0  Management  3/29/1957
# 296  Brewster H. Shaw Jr.   1978.0    8.0     Retired  5/16/1945
# 347     Sunita L. Williams  1998.0   17.0      Active  9/19/1965
#
#        birth_place  gender                                         alma_mater  \
# 113   Columbus, OH    Male     US Naval Academy; US Naval Postgraduate School
# 296  Cass City, MI    Male                            University of Wisconsin
# 347     Euclid, OH  Female  US Naval Academy; Florida Institute of Technology
#
#        undergraduate_major            graduate_major military_rank  \
# 113  Aerospace Engineering  Aeronautical Engineering       Captain
# 296  Engineering Mechanics     Engineering Mechanics       Colonel
# 347       Physical Science    Engineering Management       Captain
#
#             military_branch  space_flights  space_flight_(hr)  space_walks  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 357 non-null    object
#  1   year                 330 non-null    float64
#  2   group                330 non-null    float64
#  3   status               357 non-null    object
#  4   birth_date           357 non-null    object
#  5   birth_place          357 non-null    object
#  6   gender               357 non-null    object
#  7   alma_mater           356 non-null    object
#  8   undergraduate_major  335 non-null    object
#  9   graduate_major       298 non-null    object
#  10  military_rank        207 non-null    object
#  11  military_branch      211 non-null    object
#  12  space_flights        357 non-null    int64
#  13  space_flight_(hr)    357 non-null    int64
#  14  space_walks          357 non-null    int64
# ...

# %%
df.isnull()
# Out:
#       name   year  group  status  birth_date  birth_place  gender  alma_mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
df[df.isnull()]
# Out:
#     name  year  group status birth_date birth_place gender alma_mater  \
# 0    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 1    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 2    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 3    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 4    NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# ..   ...   ...    ...    ...        ...         ...    ...        ...
# 352  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 353  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 354  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 355  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
# 356  NaN   NaN    NaN    NaN        NaN         NaN    NaN        NaN
#
#     undergraduate_major graduate_major military_rank military_branch  \
# ...

# %%
df.isnull().sum()
# Out:
# name                     0
# year                    27
# group                   27
# status                   0
# birth_date               0
# birth_place              0
# gender                   0
# alma_mater               1
# undergraduate_major     22
# graduate_major          59
# military_rank          150
# military_branch        146
# space_flights            0
# space_flight_(hr)        0
# space_walks              0
# space_walks_(hr)         0
# missions                23
# death_date             305
# death_mission          341
# dtype: int64

# %%
df.status.value_counts()
# Out:
# Retired       220
# Deceased       51
# Active         50
# Management     36
# Name: status, dtype: int64

# %% [markdown]
# # Handling Missing Values
#
#  - Fill values
#  - Drop Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 357 non-null    object
#  1   year                 330 non-null    float64
#  2   group                330 non-null    float64
#  3   status               357 non-null    object
#  4   birth_date           357 non-null    object
#  5   birth_place          357 non-null    object
#  6   gender               357 non-null    object
#  7   alma_mater           356 non-null    object
#  8   undergraduate_major  335 non-null    object
#  9   graduate_major       298 non-null    object
#  10  military_rank        207 non-null    object
#  11  military_branch      211 non-null    object
#  12  space_flights        357 non-null    int64
#  13  space_flight_(hr)    357 non-null    int64
#  14  space_walks          357 non-null    int64
# ...

# %%
df.year.isnull().sum()
# Out:
# 27

# %%
df.year.mode()
# Out:
# 0    1978.0
# 1    1996.0
# dtype: float64

# %%
df.year = df.year.fillna(df.year.mode().mean())

# %%
df.year.isnull().sum()
# Out:
# 0

# %%
df.year.mode()[0]
# Out:
# 1987.0

# %% [markdown]
# # Handling Duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# Length: 357, dtype: bool

# %%
# df.iloc[9:,:] = np.nan

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = pd.DataFrame(np.arange(50).reshape(10,5))

# %%
df1.iloc[9,:] = np.nan

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0
# 4  20.0   NaN  22.0  23.0   NaN
# 5   NaN  26.0  27.0  28.0  29.0
# 6  30.0  31.0  32.0  33.0  34.0
# 7  35.0  36.0  37.0  38.0  39.0
# 8   NaN   NaN   NaN   NaN   NaN
# 9   NaN   NaN   NaN   NaN   NaN

# %%
df1.duplicated().sum()
# Out:
# 1
